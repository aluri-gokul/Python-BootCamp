# %% [markdown]
# # IPL DATA ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv(r'C:\Users\gokul\Downloads\IPL Matches 2008-2020.csv')

# %%
data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
data.head(10)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
# 5  335987      Jaipur  2008-04-21       SR Watson
# 6  335988   Hyderabad  2008-04-22        V Sehwag
# 7  335989     Chennai  2008-04-23       ML Hayden
# 8  335990   Hyderabad  2008-04-24       YK Pathan
# 9  335991  Chandigarh  2008-04-25   KC Sangakkara
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
data.drop(['method'],axis=1,inplace=True)

# %%
data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # MOST WINS IN IPL

# %%
temp=pd.DataFrame({'Winner':data['winner']})
count_wins=temp.value_counts()
labels=[X[0] for X in count_wins.keys()]
bar,ax=plt.subplots(figsize=(25,15))
ax=plt.pie(x=count_wins,autopct='%.2f%%',labels=labels)
plt.title("MOST WINS IN IPL",fontsize=17)
plt.show()

# %%
temp
# Out:
#                           Winner
# 0          Kolkata Knight Riders
# 1            Chennai Super Kings
# 2               Delhi Daredevils
# 3    Royal Challengers Bangalore
# 4          Kolkata Knight Riders
# ..                           ...
# 811  Royal Challengers Bangalore
# 812               Mumbai Indians
# 813          Sunrisers Hyderabad
# 814               Delhi Capitals
# 815               Mumbai Indians
#
# [816 rows x 1 columns]

# %%
count_wins
# Out:
# Winner
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# dtype: int64

# %% [markdown]
# # HIGHEST NUMBER OF WINS IN ELIMIMNATOR

# %%
sns.countplot(data['winner'][data['eliminator']=='Y'],data=data)
plt.title('HIGHEST NUMBER OF WINS IN ELIMINATOR')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\gokul\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # TOSS RESULT ANALYSIS

# %%
temp=pd.DataFrame({'Toss Results':data['toss_decision']})
count_pom=temp.value_counts()
labels=[X[0] for X in count_pom.keys()]
bar,ax=plt.subplots(figsize=(18,10))
ax=plt.pie(x=count_pom,autopct='%.0f%%',labels=labels)
plt.title("TOSS RESULTS PERCENTAGE",fontsize=17)
plt.show()

# %% [markdown]
# # NUMBER OF WINS BY TEAMS WHEN BATTING 2ND

# %%
sns.countplot(data['winner'][data['result']=='wickets'],data=data)
plt.title('COUNT OF WINS BY THE TEAMS BATTING 2ND')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\gokul\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # FAMOUS VENUE

# %%
sns.barplot(x=data['venue'].value_counts().head(10).values,
           y=data['venue'].value_counts().head(10).index)
plt.title('Famous Venue')
plt.xlabel('Venue Count')
plt.ylabel('Venue')
plt.show()

# %% [markdown]
# # TOP 10 PLAYER OF THE MATCH AWARDS

# %%
sns.barplot(x=data['player_of_match'].value_counts().head(10).values,
           y=data['player_of_match'].value_counts().head(10).index)
plt.title('TOP 10 PLAYER OF MATCH')
plt.xlabel('NO.OF AWARDS')
plt.ylabel('PLAYER NAME')
plt.show()

# %%
sns.barplot(x=data['umpire1'].value_counts().head(10).values,
           y=data['umpire1'].value_counts().head(10).index)
plt.title('TOP 10 UMPIRES')
plt.xlabel('Match Count')
plt.ylabel('Umpire-1')
plt.show()
